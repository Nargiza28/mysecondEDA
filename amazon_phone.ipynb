# %%
pip install pandas numpy matplotlib seaborn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 4.0 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 3.9 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 3.9 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 3.8 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 3.8 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np  
import matplotlib.pylab as plt
import seaborn as sns
import os
# %matplotlib inline

# %%
print(pd.__version__)
print(np.__version__)
# Out:
# 2.2.3
# 1.24.3

# %%
print(os.path.exists('input/phone_search.csv')) 


#df=pd.read_csv('input/phone_search.csv')
# Out:
# True

# %%
df=pd.read_csv('input/phone_search.csv')
df.head
# Out:
# <bound method NDFrame.head of            asin                                      product_title  \
# 0    B0BQ118F2T  Moto G Play 2023 3-Day Battery Unlocked Made f...
# 1    B0CV2W1TKZ  Samsung Galaxy A15 (SM-155M/DSN), 128GB 6GB RA...
# 2    B09SM24S8C  Samsung Galaxy A03s Cell Phone, AT&amp;T GSM U...
# 3    B0CHH1N9VY  TracFone | Motorola Moto g Pure | Locked | 32G...
# 4    B09T3MQSVP  Samsung Galaxy A13 5G Cell Phone, AT&amp;T GSM...
# ..          ...                                                ...
# 335  B0CZ3YPSRX  Gimbal Stabilizer for Smartphone, 3-Axis Phone...
# 336  B0CHB24KQJ  [True Military-Grade] Car Phone Holder【2024 St...
# 337  B01LXOPZ4W  Wall Mount Cell Phone Charging Shelf | Multi-D...
# 338  B0CXPJK7F7  Sensyne 92&quot; Cell Phone Tripod, Selfie Sti...
# 339  B0CQ237PFS  Portable Charger 33800mAh USB C Power Bank wit...
#
#     product_price product_original_price currency  product_star_rating  \
# ...

# %%
pd.set_option('display.width', 1000)

# %%
df.tail(10)
# Out:
#            asin                                      product_title product_price product_original_price currency  product_star_rating  product_num_ratings                           product_url                                      product_photo  product_num_offers  ... is_amazon_choice  is_prime  product_availability  climate_pledge_friendly               sales_volume                                           delivery has_variations unit_price  unit_count              coupon_text
# 330  B0CJ8YT4K5  Power Charger, 3-in-1 65W GaN Type C Charger, ...        $39.00                    NaN      USD                  4.6                   47  https://www.amazon.com/dp/B0CJ8YT4K5  https://m.media-amazon.com/images/I/51ZXtloQIK...                   1  ...            False      True                   NaN                    False   50+ bought in past month  FREE delivery Thu, Sep 26 Or fastest delivery ...          False        NaN         NaN                      NaN
# ...

# %%
df.columns
# Out:
# Index(['asin', 'product_title', 'product_price', 'product_original_price', 'currency', 'product_star_rating', 'product_num_ratings', 'product_url', 'product_photo', 'product_num_offers', 'product_minimum_offer_price', 'is_best_seller', 'is_amazon_choice', 'is_prime', 'product_availability', 'climate_pledge_friendly', 'sales_volume', 'delivery', 'has_variations', 'unit_price', 'unit_count', 'coupon_text'], dtype='object')

# %%
df_new=df[[ 'product_title', 'product_price', 'product_original_price', 'currency', 
'product_star_rating', 'product_num_ratings', 'product_num_offers', 
'is_best_seller', 'is_amazon_choice', 'is_prime', 'product_availability',  
'sales_volume', 'delivery']]

# %%
df_new
# Out:
#                                          product_title product_price product_original_price currency  product_star_rating  product_num_ratings  product_num_offers  is_best_seller  is_amazon_choice  is_prime                product_availability               sales_volume                                           delivery
# 0    Moto G Play 2023 3-Day Battery Unlocked Made f...        $99.00                $169.99      USD                  4.0                 1319                  16           False             False      True  Only 1 left in stock - order soon.   4K+ bought in past month  FREE delivery Tue, Sep 24 Only 1 left in stock...
# 1    Samsung Galaxy A15 (SM-155M/DSN), 128GB 6GB RA...       $153.99                    NaN      USD                  4.2                  186                   4           False             False      True                                 NaN   1K+ bought in past month                          FREE delivery Tue, Sep 24
# ...

# %%
df['product_price'].dtype
# Out:
# dtype('O')

# %%
print(df.dtypes)
# Out:
# asin                            object
# product_title                   object
# product_price                   object
# product_original_price          object
# currency                        object
# product_star_rating            float64
# product_num_ratings              int64
# product_url                     object
# product_photo                   object
# product_num_offers               int64
# product_minimum_offer_price     object
# is_best_seller                    bool
# is_amazon_choice                  bool
# is_prime                          bool
# product_availability            object
# climate_pledge_friendly           bool
# sales_volume                    object
# delivery                        object
# has_variations                    bool
# unit_price                      object
# unit_count                     float64
# coupon_text                     object
# dtype: object

# %%
df['product_price'] = pd.to_numeric(df['product_price'], errors='coerce')

# %%
print(df.dtypes)
# Out:
# asin                            object
# product_title                   object
# product_price                  float64
# product_original_price          object
# currency                        object
# product_star_rating            float64
# product_num_ratings              int64
# product_url                     object
# product_photo                   object
# product_num_offers               int64
# product_minimum_offer_price     object
# is_best_seller                    bool
# is_amazon_choice                  bool
# is_prime                          bool
# product_availability            object
# climate_pledge_friendly           bool
# sales_volume                    object
# delivery                        object
# has_variations                    bool
# unit_price                      object
# unit_count                     float64
# coupon_text                     object
# dtype: object

# %%
print(df['product_price'].isna().sum())
# Out:
# 340

# %%
df['product_price'] = df['product_price'].fillna(0)

# %%
print(df['product_price'].describe())
# Out:
# count    340.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# Name: product_price, dtype: float64

# %%
print(df.head())
# Out:
#          asin                                      product_title  product_price product_original_price currency  product_star_rating  product_num_ratings                           product_url                                      product_photo  product_num_offers  ... is_amazon_choice  is_prime                product_availability  climate_pledge_friendly               sales_volume                                           delivery has_variations unit_price  unit_count coupon_text
# 0  B0BQ118F2T  Moto G Play 2023 3-Day Battery Unlocked Made f...            0.0                $169.99      USD                  4.0                 1319  https://www.amazon.com/dp/B0BQ118F2T  https://m.media-amazon.com/images/I/61K1Fz5Lxv...                  16  ...            False      True  Only 1 left in stock - order soon.                    False   4K+ bought in past month  FREE delivery Tue, Sep 24 Only 1 left in stock...          False        NaN         NaN         NaN
# ...

# %%
df.head()
# Out:
#          asin                                      product_title  product_price product_original_price currency  product_star_rating  product_num_ratings                           product_url                                      product_photo  product_num_offers  ... is_amazon_choice  is_prime                product_availability  climate_pledge_friendly               sales_volume                                           delivery has_variations unit_price  unit_count coupon_text
# 0  B0BQ118F2T  Moto G Play 2023 3-Day Battery Unlocked Made f...            0.0                $169.99      USD                  4.0                 1319  https://www.amazon.com/dp/B0BQ118F2T  https://m.media-amazon.com/images/I/61K1Fz5Lxv...                  16  ...            False      True  Only 1 left in stock - order soon.                    False   4K+ bought in past month  FREE delivery Tue, Sep 24 Only 1 left in stock...          False        NaN         NaN         NaN
# ...

# %%
df=pd.read_csv('input/phone_search.csv')
pd.set_option('display.width', 1000)
df.head(10)
# Out:
#          asin                                      product_title product_price product_original_price currency  product_star_rating  product_num_ratings                           product_url                                      product_photo  product_num_offers  ... is_amazon_choice  is_prime                product_availability  climate_pledge_friendly               sales_volume                                           delivery has_variations unit_price  unit_count coupon_text
# 0  B0BQ118F2T  Moto G Play 2023 3-Day Battery Unlocked Made f...        $99.00                $169.99      USD                  4.0                 1319  https://www.amazon.com/dp/B0BQ118F2T  https://m.media-amazon.com/images/I/61K1Fz5Lxv...                  16  ...            False      True  Only 1 left in stock - order soon.                    False   4K+ bought in past month  FREE delivery Tue, Sep 24 Only 1 left in stock...          False        NaN         NaN         NaN
# ...

# %%
df['product_price'] = df['product_price'].replace({'\$': ''}, regex=True)

# %%
df['product_price'] = pd.to_numeric(df['product_price'], errors='coerce')

# %%
print("\nCount of NaN values in 'product_price':")
print(df['product_price'].isna().sum())
# Out:
# Count of NaN values in 'product_price':
# 7

# %%
print(df[df['product_price'].isna()])
# Out:
#            asin                                      product_title  product_price product_original_price currency  product_star_rating  product_num_ratings                           product_url                                      product_photo  product_num_offers  ... is_amazon_choice  is_prime                product_availability  climate_pledge_friendly               sales_volume                                           delivery has_variations unit_price  unit_count coupon_text
# 64   B0CMDLJR6K  SAMSUNG Galaxy S24 Cell Phone, 256GB AI Smartp...            NaN                    NaN      NaN                  4.4                  424  https://www.amazon.com/dp/B0CMDLJR6K  https://m.media-amazon.com/images/I/71n6yF1SA4...                   1  ...            False      True                                 NaN                     True  200+ bought in past month                          FREE delivery Thu, Sep 26          False        NaN         NaN         NaN
# ...

# %%
df[df['product_price'].isna()]
# Out:
#            asin                                      product_title  product_price product_original_price currency  product_star_rating  product_num_ratings                           product_url                                      product_photo  product_num_offers  ... is_amazon_choice  is_prime                product_availability  climate_pledge_friendly               sales_volume                                           delivery has_variations unit_price  unit_count coupon_text
# 64   B0CMDLJR6K  SAMSUNG Galaxy S24 Cell Phone, 256GB AI Smartp...            NaN                    NaN      NaN                  4.4                  424  https://www.amazon.com/dp/B0CMDLJR6K  https://m.media-amazon.com/images/I/71n6yF1SA4...                   1  ...            False      True                                 NaN                     True  200+ bought in past month                          FREE delivery Thu, Sep 26          False        NaN         NaN         NaN
# ...

# %%
df['product_price'] = df['product_price'].fillna(0)

# %%
df[df['product_price'].isna()]
# Out:
# Empty DataFrame
# Columns: [asin, product_title, product_price, product_original_price, currency, product_star_rating, product_num_ratings, product_url, product_photo, product_num_offers, product_minimum_offer_price, is_best_seller, is_amazon_choice, is_prime, product_availability, climate_pledge_friendly, sales_volume, delivery, has_variations, unit_price, unit_count, coupon_text]
# Index: []
#
# [0 rows x 22 columns]

# %%
df_f=df[df['product_star_rating']==5]
df_f
# Out:
#            asin                                      product_title  product_price product_original_price currency  product_star_rating  product_num_ratings                           product_url                                      product_photo  product_num_offers  ... is_amazon_choice  is_prime  product_availability  climate_pledge_friendly              sales_volume                                           delivery has_variations unit_price  unit_count           coupon_text
# 195  B0DCVTQBHL  Magnetic for iPhone 16 Case,[Compatible with M...          21.99                    NaN      USD                  5.0                    2  https://www.amazon.com/dp/B0DCVTQBHL  https://m.media-amazon.com/images/I/71OKImTKQ4...                   1  ...            False      True                   NaN                    False                       NaN  FREE delivery Fri, Sep 27 on $35 of items ship...          False        NaN         NaN  Save 15% with coupon
# ...

# %%
df=df[[ 'product_title', 'product_price', 'product_original_price', 'currency', 
'product_star_rating', 'product_num_ratings', 'product_num_offers', 
'is_best_seller', 'is_amazon_choice', 'is_prime', 'product_availability',  
'sales_volume', 'delivery']]

# %%
df
# Out:
#                                          product_title  product_price product_original_price currency  product_star_rating  product_num_ratings  product_num_offers  is_best_seller  is_amazon_choice  is_prime                product_availability               sales_volume                                           delivery
# 0    Moto G Play 2023 3-Day Battery Unlocked Made f...          99.00                $169.99      USD                  4.0                 1319                  16           False             False      True  Only 1 left in stock - order soon.   4K+ bought in past month  FREE delivery Tue, Sep 24 Only 1 left in stock...
# 1    Samsung Galaxy A15 (SM-155M/DSN), 128GB 6GB RA...         153.99                    NaN      USD                  4.2                  186                   4           False             False      True                                 NaN   1K+ bought in past month                          FREE delivery Tue, Sep 24
# ...

# %%
df_t=df[df['is_best_seller']==True]
df_t
# Out:
#                                          product_title  product_price product_original_price currency  product_star_rating  product_num_ratings  product_num_offers  is_best_seller  is_amazon_choice  is_prime                product_availability               sales_volume                                           delivery
# 63   Apple iPhone 12, 128GB, Black - Fully Unlocked...         287.30                $314.99      USD                  4.1                25638                  20            True             False     False  Only 1 left in stock - order soon.   2K+ bought in past month  FREE delivery Sep 24 - 26 Only 1 left in stock...
# 338  Sensyne 92&quot; Cell Phone Tripod, Selfie Sti...          29.99                    NaN      USD                  4.6                29066                   1            True             False      True                                 NaN  300+ bought in past month  FREE delivery Tue, Sep 24 on $35 of items ship...

# %%
df.describe()
# Out:
#        product_price  product_star_rating  product_num_ratings  product_num_offers
# count     340.000000           337.000000           340.000000          340.000000
# mean      158.259735             4.087537          2744.050000            8.426471
# std       165.892669             0.383544          7331.816833           10.798389
# min         0.000000             1.600000             0.000000            1.000000
# 25%        56.510000             3.900000           135.250000            1.750000
# 50%       104.920000             4.100000           503.500000            4.000000
# 75%       195.680000             4.300000          1874.250000           11.000000
# max       993.900000             5.000000         64977.000000           83.000000

# %%
df['is_best_seller'].value_counts()
# Out:
# is_best_seller
# False    338
# True       2
# Name: count, dtype: int64

# %%
sns.boxplot(x='is_best_seller', y='product_price', data=df)
plt.show()

# %%
sns.boxplot(x='product_num_ratings', y='product_price', data=df)
plt.show()

# %%
sns.boxplot(x='product_price', y='product_num_ratings', data=df)
plt.show()

# %%
sns.boxplot(x='is_best_seller', y='product_num_ratings', data=df)
plt.show()

# %%
numeric_df = df.select_dtypes(include='number')
correlation_matrix = numeric_df.corr()
correlation_matrix
# Out:
#                      product_price  product_star_rating  product_num_ratings  product_num_offers
# product_price             1.000000             0.209118            -0.057576            0.024472
# product_star_rating       0.209118             1.000000             0.158313           -0.033936
# product_num_ratings      -0.057576             0.158313             1.000000            0.067936
# product_num_offers        0.024472            -0.033936             0.067936            1.000000

# %%
df_sub=df[df['product_star_rating']>4]
df_sub
# Out:
#                                          product_title  product_price product_original_price currency  product_star_rating  product_num_ratings  product_num_offers  is_best_seller  is_amazon_choice  is_prime product_availability               sales_volume                                           delivery
# 1    Samsung Galaxy A15 (SM-155M/DSN), 128GB 6GB RA...         153.99                    NaN      USD                  4.2                  186                   4           False             False      True                  NaN   1K+ bought in past month                          FREE delivery Tue, Sep 24
# 3    TracFone | Motorola Moto g Pure | Locked | 32G...          49.99                    NaN      USD                  4.2                 2814                   3           False             False      True                  NaN  500+ bought in past month                          FREE delivery Tue, Sep 24
# ...

# %%
number_of_products = df_sub.shape[0]  # shape returns (rows, columns), so [0] gives you the row count
print("Number of products with a star rating greater than 4.5:", number_of_products)
df_sub
# Out:
# Number of products with a star rating greater than 4.5: 204
#                                          product_title  product_price product_original_price currency  product_star_rating  product_num_ratings  product_num_offers  is_best_seller  is_amazon_choice  is_prime product_availability               sales_volume                                           delivery
# 1    Samsung Galaxy A15 (SM-155M/DSN), 128GB 6GB RA...         153.99                    NaN      USD                  4.2                  186                   4           False             False      True                  NaN   1K+ bought in past month                          FREE delivery Tue, Sep 24
# 3    TracFone | Motorola Moto g Pure | Locked | 32G...          49.99                    NaN      USD                  4.2                 2814                   3           False             False      True                  NaN  500+ bought in past month                          FREE delivery Tue, Sep 24
# ...

# %%
df[df['product_star_rating']>4.5].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
number_of_products = df_sub.shape[0]
print("Number of products with a star rating greater than 4.5:", number_of_products)
# Out:
# Number of products with a star rating greater than 4.5: 204

# %%
from ydata_profiling import ProfileReport

# %%
import numpy as np 
print(np.__version__)
# Out:
# 1.24.3

# %%
profile = ProfileReport(
    df, title="Amazon store report", html={"style": {"full_width": True}}, sort=None
)

# %%
profile.to_file("amazon_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
